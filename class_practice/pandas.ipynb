# %% [markdown]
# ## Pandas

# %%
## Padas is uses for 


its provide two primary datastructure 
1 series
2 Data frames _(2D tabular)

# %%
import pandas as pd

s = pd.Series([10, 20, 30])

df = pd.DataFrame({
'name': ['Asha','Ravi','Maya'],
'age': [21, 22, 20]
})

print(s)
print(df)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64
#    name  age
# 0  Asha   21
# 1  Ravi   22
# 2  Maya   20

# %%
print(df.head(2))
# Out:
#    name  age
# 0  Asha   21
# 1  Ravi   22

# %%
print(df.tail(1))
# Out:
#    name  age
# 2  Maya   20

# %%
print(df.shape)
# Out:
# (3, 2)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   age     3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 176.0+ bytes
# None

# %%
print(df.describe())
# Out:
#         age
# count   3.0
# mean   21.0
# std     1.0
# min    20.0
# 25%    20.5
# 50%    21.0
# 75%    21.5
# max    22.0

# %%
print(df.columns)
print(df.index)
print(df.dtypes)
# Out:
# Index(['name', 'age'], dtype='object')
# RangeIndex(start=0, stop=3, step=1)
# name    object
# age      int64
# dtype: object
