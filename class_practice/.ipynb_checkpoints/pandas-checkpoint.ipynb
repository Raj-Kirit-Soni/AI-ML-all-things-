# %% [markdown]
# ## Pandas

# %%
## Padas is uses for 


its provide two primary datastructure 
1 series
2 Data frames _(2D tabular)

# %%
import pandas as pd

s = pd.Series([10, 20, 30])

df = pd.DataFrame({
'name': ['Asha','Ravi','Maya'],
'age': [21, 22, 20]
})

print(s)
print(df)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64
#    name  age
# 0  Asha   21
# 1  Ravi   22
# 2  Maya   20

# %%
print(df.head(2))
# Out:
#    name  age
# 0  Asha   21
# 1  Ravi   22

# %%
print(df.tail(1))
# Out:
#    name  age
# 2  Maya   20
