# %% [markdown]
# ##Match-case

# %%
http_status = int(input("Enter the http code"))

match http_status :
    case 200:
        print(" the server is Running properly")
    case 404:
        print(" Bad Request")
    case 500:
        print("Internal server error")
    case _:
        print("Enter code is invalid")
# Out:
# Enter the http code 3456
# Enter code is invalid

# %%
color = input("Enter the color name ")

match color:
    case "red":
        print(" Vehichle")
    case "green":
        print(" Bad Request")
    case "yelow":
        print("Internal server error")
    case _:
        print("Enter code is invalid")
