# %%
# Q1. Write a program that takes as input. Using conditional statements,
# calculate the finaltax rate based on these rules:
# • If salary < 30,000 → 5%
# • If salary is 30,000–70,000 → 15%
# • If salary > 70,000 → 25%

salary = int(input("ENter the salary to calculate the tax"))

if (salary < 30000):
    tax = salary * 0.05
    
elif (salary < 30000):
    tax = salary * 0.15
elif(salary < 30000):
     tax = salary * 0.25

print(tax)
# Out:
# ENter the salary to calculate the tax 100000
# 500.0
