# %%
age = int(input("Enter your age"))

if (age>=18):
    print("voter is eligible")
else:
    print("voter is under age")
# Out:
# Enter your age 12
# voter is under age

# %%
#Traffic Light

# %%
color = input("Enter the color ")

if (color=="Red"):
    print("STOP")
elif(color == "Green"):
    print("GO")
else :
    print("Wait")
# Out:
# Enter the color  Green
# GO

# %%
age=int(input("Enter the age"))
if (age>=18):
    print("Adult")
elif (age >= 13 and age <18):
    print("teenager")
else:
    print("Child")
# Out:
# Enter the age 20
# Adult

# %%
# authentication

# %%
userid= input("ENter the userid")
password = input("Enter the password")

if (userid == "Rajkirit" and password == "1234"):
    print("Login Successfull")
elif(userid != "Rajkirit"):
    print("Wrong Password")
else:
    print("Wrong password")
# Out:
# ENter the userid Rajkirit
# Enter the password 4559
# Wrong password

# %%
# program for the odd even 

n = int(input("Enter the number"))

if(n%5==0):
    print("this number multiple of 5")
else:
    print("Not multiple")
# Out:
# Enter the number 150
# this number multiple of 5
