# %%
# # Product store

# Design & Create  an  online  store  for Product (Name , Price)
# Track total product being created 
# Create a statc method to calculate discount on each product based on a % product


class Product: 
    def __init__(self, name, price):
        self.name = name 
        self.price = price
        print(f"this is the product {self.name} and {self.price} in Rupees")

    

L1= Product("laptop ASUS TUF", 90_000)
# Out:
# this is the product laptop ASUS TUF and 90000 in Rupees
