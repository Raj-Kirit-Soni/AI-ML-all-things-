# %%
age =21

# %%
pi = 3.14
pi
# Out:
# 3.14

# %%
name = "raj" #str

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
student = {   #dictionary
    "name" : "rajkiritsoni",
    "age" : 21
}
print(student)
# Out:
# {'name': 'rajkiritsoni', 'age': 21}

# %%
is_run = True
print(is_run)
# Out:
# True

# %%
a, b, c = 1, 2, 3

# %%
data = None

# %%
z = 2 + 3j
