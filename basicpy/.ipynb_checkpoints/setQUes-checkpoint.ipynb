# %%
info = [("Rahul","English"),
        ("Rohan","science"),
        ("Rohit","sst"),
        ("Ronak","science"),
        ("Roshan","English"),
        ("Raj","maths")]

# ext = info.pop(2)
# print(ext)

for in range(0,len(info)):
# Out:
# ('Rohit', 'sst')
