# %% [markdown]
# ## basic variable

# %%
name = "Raj"        # string
age = 22            # integer
height = 5.8        # float
is_student = True   # boolean

# %% [markdown]
# ### Tupple

# %%
colors = ("red", "green", "blue")

# %%
fruits = ["apple", "banana", "mango"]

# %%
numbers = {1, 2, 3, 4}

# %%
student = {
    "name": "Raj",
    "age": 22
}
